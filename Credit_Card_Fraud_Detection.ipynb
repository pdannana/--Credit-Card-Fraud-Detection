# %% [markdown]
# <a href="https://colab.research.google.com/github/pdannana/--Credit-Card-Fraud-Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn imbalanced-learn

# %%
import pandas as pd
from google.colab import files

# Step 1: Upload the file
uploaded = files.upload()

# Step 2: Load the dataset
# Get the file name from the uploaded files dictionary
file_name = next(iter(uploaded))

# Load the dataset into a DataFrame
df = pd.read_csv(file_name)

# Step 3: Display the first few rows of the DataFrame to confirm it's loaded correctly
df.head()
# Out:
#      <input type="file" id="files-0e2c7ccb-2d95-44a4-9cdc-ebee45eba872" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e2c7ccb-2d95-44a4-9cdc-ebee45eba872">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pandas scikit-learn imbalanced-learn

# %%
import pandas as pd
from google.colab import files

# Step 1: Upload the file
uploaded = files.upload()

# Step 2: Load the dataset
# Get the file name from the uploaded files dictionary
file_name = next(iter(uploaded))

# Load the dataset into a DataFrame
df = pd.read_csv(file_name)

# Display the first few rows of the DataFrame to confirm it's loaded correctly
print(df.head())
# Out:
#      <input type="file" id="files-d77de27c-fa64-4edd-81c2-58a95fb3d142" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d77de27c-fa64-4edd-81c2-58a95fb3d142">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Display information about the dataframe
df.info()

# Display statistical summary
df.describe()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49692 entries, 0 to 49691
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    49692 non-null  int64
#  1   V1      49692 non-null  float64
#  2   V2      49692 non-null  float64
#  3   V3      49692 non-null  float64
#  4   V4      49692 non-null  float64
#  5   V5      49692 non-null  float64
#  6   V6      49692 non-null  float64
#  7   V7      49692 non-null  float64
#  8   V8      49692 non-null  float64
#  9   V9      49692 non-null  float64
#  10  V10     49692 non-null  float64
#  11  V11     49692 non-null  float64
#  12  V12     49692 non-null  float64
#  13  V13     49692 non-null  float64
#  14  V14     49692 non-null  float64
#  15  V15     49692 non-null  float64
#  16  V16     49692 non-null  float64
#  17  V17     49692 non-null  float64
#  18  V18     49692 non-null  float64
#  19  V19     49692 non-null  float64
# ...

# %%
# Example of handling missing values
df = df.dropna()  # Dropping rows with missing values
# Alternatively, you could fill missing values using df.fillna()

# Check again for missing values to ensure they are handled
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# class     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Example of encoding a categorical variable
# df['categorical_column'] = LabelEncoder().fit_transform(df['categorical_column'])

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Scale numerical features
# df[['feature1', 'feature2']] = scaler.fit_transform(df[['feature1', 'feature2']])

# %%
# Display the column names in the dataframe
print(df.columns)
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
# Display information about the dataframe
df.info()

# Display statistical summary
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Check the distribution of the target variable
print(df['class'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49692 entries, 0 to 49691
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    49692 non-null  int64
#  1   V1      49692 non-null  float64
#  2   V2      49692 non-null  float64
#  3   V3      49692 non-null  float64
#  4   V4      49692 non-null  float64
#  5   V5      49692 non-null  float64
#  6   V6      49692 non-null  float64
#  7   V7      49692 non-null  float64
#  8   V8      49692 non-null  float64
#  9   V9      49692 non-null  float64
#  10  V10     49692 non-null  float64
#  11  V11     49692 non-null  float64
#  12  V12     49692 non-null  float64
#  13  V13     49692 non-null  float64
#  14  V14     49692 non-null  float64
#  15  V15     49692 non-null  float64
#  16  V16     49692 non-null  float64
#  17  V17     49692 non-null  float64
#  18  V18     49692 non-null  float64
#  19  V19     49692 non-null  float64
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Define features (X) and target (y)
X = df.drop('class', axis=1)
y = df['class']

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Define features (X) and target (y)
X = df.drop('class', axis=1)
y = df['class']

# Encode the target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Define models
models = {
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'XGBoost': XGBClassifier()
}

# Train and evaluate each model
for name, model in models.items():
    print(f"\n{name}")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print("Classification Report:")
    print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

    print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Random Forest
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00      9847
#          yes       0.95      0.79      0.86        92
#
#     accuracy                           1.00      9939
#    macro avg       0.97      0.90      0.93      9939
# weighted avg       1.00      1.00      1.00      9939
#
# Confusion Matrix:
# [[9843    4]
#  [  19   73]]
# Accuracy: 0.9976858838917396
#
# Gradient Boosting
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00      9847
#          yes       0.87      0.77      0.82        92
#
#     accuracy                           1.00      9939
#    macro avg       0.93      0.89      0.91      9939
# weighted avg       1.00      1.00      1.00      9939
#
# Confusion Matrix:
# [[9836   11]
#  [  21   71]]
# Accuracy: 0.996780360197203
#
# XGBoost
# Classification Report:
# ...

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to the training data
smote = SMOTE()
X_res, y_res = smote.fit_resample(X_train, y_train)

# Re-train and evaluate models on the resampled data
for name, model in models.items():
    print(f"\n{name} with SMOTE")
    model.fit(X_res, y_res)
    y_pred = model.predict(X_test)

    print("Classification Report:")
    print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

    print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Random Forest with SMOTE
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       1.00      1.00      1.00      9847
#          yes       0.90      0.79      0.84        92
#
#     accuracy                           1.00      9939
#    macro avg       0.95      0.90      0.92      9939
# weighted avg       1.00      1.00      1.00      9939
#
# Confusion Matrix:
# [[9839    8]
#  [  19   73]]
# Accuracy: 0.99728342891639
#
# Gradient Boosting with SMOTE
# Classification Report:
#               precision    recall  f1-score   support
#
#           no       1.00      0.99      0.99      9847
#          yes       0.45      0.89      0.60        92
#
#     accuracy                           0.99      9939
#    macro avg       0.72      0.94      0.80      9939
# weighted avg       0.99      0.99      0.99      9939
#
# Confusion Matrix:
# [[9746  101]
#  [  10   82]]
# Accuracy: 0.9888318744340477
#
# XGBoost with SMOTE
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve, roc_auc_score

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

# Function to plot ROC curve
def plot_roc_curve(model, X_test, y_test, title):
    y_pred_prob = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
    auc = roc_auc_score(y_test, y_pred_prob)
    plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend()
    plt.show()

# Plotting results
for name, model in models.items():
    print(f"\n{name} with SMOTE")
    y_pred = model.predict(X_test)
    plot_confusion_matrix(y_test, y_pred, f"Confusion Matrix: {name}")
    plot_roc_curve(model, X_test, y_test, f"ROC Curve: {name}")
# Out:
# Random Forest with SMOTE
# Gradient Boosting with SMOTE
# XGBoost with SMOTE

# %%
# !pip install xgboost
import xgboost as xgb

# Applying XGBoost Classifier
xgb_classifier = xgb.XGBClassifier(n_estimators=100, random_state=42)
xgb_classifier.fit(X_train, y_train)

# Predictions
y_pred_xgb = xgb_classifier.predict(X_test)

# Evaluate the model
print("Classification Report:\n", classification_report(y_test, y_pred_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
print("Accuracy Score:\n", accuracy_score(y_test, y_pred_xgb))

# Plotting the confusion matrix
conf_matrix_xgb = confusion_matrix(y_test, y_pred_xgb)
sns.heatmap(conf_matrix_xgb, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (XGBoost)')
plt.show()
# Out:
# ...
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      9847
#            1       0.97      0.80      0.88        92
#
#     accuracy                           1.00      9939
#    macro avg       0.99      0.90      0.94      9939
# weighted avg       1.00      1.00      1.00      9939
#
# Confusion Matrix:
#  [[9845    2]
#  [  18   74]]
# Accuracy Score:
#  0.9979877251232518

# %%
from google.colab import files
import pandas as pd
import io

# Upload the file
uploaded = files.upload()

# Load the dataset
for filename in uploaded.keys():
    print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
    df = pd.read_csv(io.BytesIO(uploaded[filename]))

# Display the first few rows of the dataframe
df.head()
# Out:
#      <input type="file" id="files-777c9023-fe7d-48f0-a798-0bcb37cd7f9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-777c9023-fe7d-48f0-a798-0bcb37cd7f9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of transaction amounts
plt.figure(figsize=(10, 6))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.savefig('amount.png')
plt.show()

# Scatter plot of two features (e.g., V1 vs V2)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='V1', y='V2', hue='class', data=df)
plt.title('Scatter Plot of V1 vs V2')
plt.xlabel('V1')
plt.ylabel('V2')
plt.legend(title='Class')
plt.savefig('creditscatter.png')
plt.show()

# Time series plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Time', y='Amount', hue='class', data=df)
plt.title('Transactions Over Time')
plt.xlabel('Time')
plt.ylabel('Amount')
plt.legend(title='Class')
plt.savefig('time.png')
plt.show()

# Class distribution before balancing
plt.figure(figsize=(10, 6))
sns.countplot(x='class', data=df)
plt.title('Class Distribution Before Balancing')
plt.xlabel('Class')
plt.ylabel('Count')
plt.savefig('unbalanced.png')
plt.show()

# Assuming you have balanced the dataset
# Class distribution after balancing
# df_balanced = your_balanced_dataframe
# Example: Use SMOTE for balancing
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X = df.drop(columns=['class'])
y = df['class']
X_resampled, y_resampled = smote.fit_resample(X, y)
df_balanced = pd.DataFrame(X_resampled, columns=X.columns)
df_balanced['class'] = y_resampled

plt.figure(figsize=(10, 6))
sns.countplot(x='class', data=df_balanced)
plt.title('Class Distribution After Balancing')
plt.xlabel('Class')
plt.ylabel('Count')
plt.savefig('balanced_plot.png')
plt.show()
